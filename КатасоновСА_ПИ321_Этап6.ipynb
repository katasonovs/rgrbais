# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
reg = linear_model.LinearRegression()
np.random.seed(19130167)
A = []
B = []
T = []
N = 10000
n = 1000

# %%
for i in range(n):
  t = time.time()
  x = np.random.uniform(low=150, high=200, size=N)
  e  = np.random.normal(loc=0, scale=10, size=N)
  y = -100 + x + e
  reg.fit(x.reshape(-1,1), y.reshape (-1, 1))
  A.append (reg.intercept_[0])
  B.append(reg.coef_[0][0])
  T.append(time.time() - t)

# %%
plt.figure(figsize=(10,6))
plt.hist(B, bins = 20, edgecolor = 'black', color='white')
plt.title('Histogram of B estimates')
plt.show()

# %%
min(T), np.median(T), max(T)
# Out:
# (0.0012497901916503906, 0.0013042688369750977, 0.004243612289428711)

# %%
plt.figure(figsize=(10,4))
plt.plot(T, marker=".")
plt.show()

# %% [markdown]
# Возьмем диапозон от 860 до 1000

# %%
plt.figure(figsize=(10,4))
plt.plot(T[860:900], marker=".")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(T[490:550], marker=".")
plt.show()

# %% [markdown]
# В соответсвии с методичкой -

# %%
plt.figure(figsize=(10,4))
plt.hist(T[300:500], bins=30,edgecolor='black', color = 'white')
plt.show()

# %% [markdown]
# Измененный вариант -

# %%
plt.figure(figsize=(10,4))
plt.hist(T[850:1000],range=(0.0013,0.00136), bins=30,edgecolor='black', color = 'white')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(T, marker=".")
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(T[860:1000], marker=".")
plt.show()

# %% [markdown]
# Изменим диапзон Т

# %%
plt.figure(figsize=(10,4))
plt.hist(T[860:1000], bins=30,edgecolor='black', color = 'white')
plt.show()

# %% [markdown]
# Изменим еще немного

# %%
plt.figure(figsize=(10,4))
plt.hist(T[860:1000], bins=30,range=(0.00125,0.001305),edgecolor='black', color = 'white')
plt.show()
